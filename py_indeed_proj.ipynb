# %%
import pandas as pd
import numpy as np
import re
#import math
import time
# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %% [raw]
# reviews=pd.read_csv('indeed_reviews.csv')

# %%
reviews
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-470bec042f77> in <module>()
# ----> 1 reviews
#
# NameError: name 'reviews' is not defined

# %%
reviews['date']=[reviews.date[i].split(',',1)[1] for i in range(len(reviews))]
# changing the date to years

# %%
reviews=reviews[['company','location','date','jobtitle','tot_review','Comp_Benef_review',
         'Job_Culture_review','Job_Security_Adv','Management_review','Work_Life_review','title','review_content']]
#reordering the columns

# %%
reviews.head()
# Out:
#   company                          location   date  \
# 0   Apple  1981 Broadway New York, NY 10023   2016
# 1   Apple                     Lancaster, PA   2018
# 2   Apple                Silicon Valley, CA   2018
# 3   Apple                   Los Angeles, CA   2018
# 4   Apple                     Cupertino, CA   2018
#
#                               jobtitle  tot_review  Comp_Benef_review  \
# 0                   Service Specialist          80                100
# 1                                 Tech         100                 80
# 2                   freelance designer          60                 40
# 3                           Specialist          60                 60
# 4  Sr Manager of Platform Architecture          60                100
#
#    Job_Culture_review  Job_Security_Adv  Management_review  Work_Life_review  \
# 0                  80                60                 80                80
# 1                  80               100                 80               100
# ...

# %%
## filtering reviewers who gave only final score withount scoring other elements =0
reviews=reviews[sum([reviews.Comp_Benef_review ,reviews.Job_Culture_review ,
             reviews.Job_Security_Adv,reviews.Management_review,reviews.Work_Life_review])!=0]

# %%
plt.figure(figsize=(12,6))
reviews.groupby('company')['tot_review'].mean().sort_values(ascending=False).plot.bar(color='b')

# %%
reviews.groupby('company')['Comp_Benef_review'].mean().sort_values(ascending=False).plot.bar(color='b')

# %%
reviews.groupby('company')['Job_Culture_review'].mean().sort_values(ascending=False).plot.bar(color='b')

# %%
reviews.groupby('company')['Job_Security_Adv'].mean().sort_values(ascending=False).plot.bar(color='b')

# %%
reviews.groupby('company')['Management_review'].mean().sort_values(ascending=False).plot.bar(color='b')

# %%
reviews.groupby('company')['Work_Life_review'].mean().sort_values(ascending=False).plot.bar(color='b')

# %%
totGrid = sns.FacetGrid(reviews, col='company', hue="company", palette="Set1", size=4)
totGrid.map(sns.distplot,'tot_review',kde=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-00b1f170eb2f> in <module>()
# ----> 1 set(reviews.company)
#
# NameError: name 'reviews' is not defined
